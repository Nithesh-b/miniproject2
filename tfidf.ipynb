was my\ntemper to avoid a crowd and to attach myself fervently to a few. I was\nindifferent, therefore, to my school-fellows in general; but I united\nmyself in the bonds of the closest friendship to one among them. Henry\nClerval was the son of a merchant of Geneva. He was a boy of singular\ntalent and fancy. He loved enterprise, hardship, and even danger for\nits own sake. He was deeply read in books of chivalry and romance.  He\ncomposed heroic songs and began to write many a tale of enchantment and\nknightly adventure. He tried to make us act plays and to enter into\nmasquerades, in which the characters were drawn from the heroes of\nRoncesvalles, of the Round Table of King Arthur, and the chivalrous\ntrain wh ...

# %%
def _create_frequency_table(text_str) -> dict:
    """
    we create a dictionary for the word frequency table.
    For this, we should only use the words that are not part of the stopWords array.
    Removing stop words and making frequency table
    Stemmer - an algorithm to bring words to its root word.
    :rtype: dict
    """
    stopWords = set(stopwords.words("english"))
    words = word_tokenize(text_string)
    ps = PorterStemmer()

    freqTable = dict()
    for word in words:
        word = ps.stem(word)
        if word in stopWords:
            continue
        if word in freqTable:
            freqTable[word] += 1
        else:
            freqTable[word] = 1

    return freqTable

# %%
def _create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("english"))
    ps = PorterStemmer()

    for sent in sentences:
        freq_table = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            word = ps.stem(word)
            if word in stopWords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:15]] = freq_table

    return frequency_matrix

# %%
def _create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix

# %%
def _create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table

# %%
def _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix

# %%
def _create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(),
                                                    f_table2.items()):  # here, keys are the same in both the table
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix

# %%
def _score_sentences(tf_idf_matrix) -> dict:
    """
    score a sentence by its word's TF
    Basic algorithm: adding the TF frequency of every non-stop word in a sentence divided by total no of words in a sentence.
    :rtype: dict
    """

    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0

        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence += score

        sentenceValue[sent] = total_score_per_sentence / count_words_in_sentence

    return sentenceValue

# %%
def _find_average_score(sentenceValue) -> int:
    """
    Find the average score from the sentence value dictionary
    :rtype: int
    """
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original summary_text
    average = (sumValues / len(sentenceValue))

    return average

# %%
def _generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:15] in sentenceValue and sentenceValue[sentence[:15]] >= (threshold):
            summary += " " + sentence
            sentence_count += 1

    return summary

# %%
def run_summarization(text):
    """
    :param text: Plain summary_text of long article
    :return: summarized summary_text
    """

    '''
    We already have a sentence tokenizer, so we just need 
    to run the sent_tokenize() method to create the array of sentences.
    '''
    # 1 Sentence Tokenize
    sentences = sent_tokenize(text)
    total_documents = len(sentences)
    #print(sentences)

    # 2 Create the Frequency matrix of the words in each sentence.
    freq_matrix = _create_frequency_matrix(sentences)
    #print(freq_matrix)

    '''
    Term frequency (TF) is how often a word appears in a document, divided by how many words are there in a document.
    '''
    # 3 Calculate TermFrequency and generate a matrix
    tf_matrix = _create_tf_matrix(freq_matrix)
    #print(tf_matrix)

    # 4 creating table for documents per words
    count_doc_per_words = _create_documents_per_words(freq_matrix)
    #print(count_doc_per_words)

    '''
    Inverse document frequency (IDF) is how unique or rare a word is.
    '''
    # 5 Calculate IDF and generate a matrix
    idf_matrix = _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents)
    #print(idf_matrix)

    # 6 Calculate TF-IDF and generate a matrix
    tf_idf_matrix = _create_tf_idf_matrix(tf_matrix, idf_matrix)
    #print(tf_idf_matrix)

    # 7 Important Algorithm: score the sentences
    sentence_scores = _score_sentences(tf_idf_matrix)
    #print(sentence_scores)

    # 8 Find the threshold
    threshold = _find_average_score(sentence_scores)
    #print(threshold)

    # 9 Important Algorithm: Generate the summary
    summary = _generate_summary(sentences, sentence_scores, 1.3 * threshold)
    return summary

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer
#  'adventure': 16,
#  'aerial': 17,
#  'affairs': 18,
#  'affection': 19,
#  'afterwards': 20,
#  'again': 21,
#  'against': 22,
#  'age': 23,
#  'ages': 24,
#  'aggravation': 25,
#  'agitated': 26,
#  'agony': 27,
#  'agrippa': 28,
#  'air': 29,
#  'akin': 30,
#  'alarming': 31,
#  'alas': 32,
#  'all': 33,
#  'almost': 34,
#  'alpine': 35,
#  'already': 36,
#  'also': 37,
#  'although': 38,
#  'always': 39,
#  'am': 40,
#  'among': 41,
#  'amounted': 42,
#  'ample': 43,
#  'an': 44,
#  'ancestors': 45,
#  'and': 46,
#  'another': 47,
#  'anxiety': 48,
#  'any': 49,
#  'appearance': 50,
#  'appearances': 51,
#  'appeared': 52,
#  'application': 53,
#  'applied': 54,
#  'apprehension': 55,
#  'apprehensions': 56,
#  'ardent': 57,
#  'ardour': 58,
#  'are': 59,
#  'arguments': 60,
#  'around': 61,
#  'arrive': 62,
#  'arrived': 63,
#  'arteries': 64,
#  'arthur': 65,
#  'as': 66,
#  'ascribed': 67,
#  'asked': 68,
#  'asks': 69,
#  'assistance': 70,
#  'assured': 71,
#  'astonishment': 72,
#  'at': 73,
#  'attach': 74,
#  'attained': 75,
#  'attainment': 76,
#  'attend': 77,
#  'attendants': 78,
#  'attended': 79,
#  'attending': 80,
#  'attention': 81,
#  'attentions': 82,
#  'attest': 83,
#  'avoid': 84,
#  'away': 85,
#  'babe': 86,
#  'banished': 87,
#  'be': 88,
#  'bear': 89,
#  'beaufort': 90,
#  'beautiful': 91,
#  'beauty': 92,
#  'became': 93,
#  'become': 94,
#  'been': 95,
#  'befitting': 96,
#  'before': 97,
#  'began': 98,
#  'begin': 99,
#  'beheld': 100,
#  'behold': 101,
#  'being': 102,
#  'beings': 103,
#  'beloved': 104,
#  'belrive': 105,
#  'beneath': 106,
#  'benevolent': 107,
#  'benignity': 108,
#  'best': 109,
#  'better': 110,
#  'birth': 111,
#  'bitterly': 112,
#  'black': 113,
#  'blood': 114,
#  'bonds': 115,
#  'books': 116,
#  'boy': 117,
#  'breathed': 118,
#  'bring': 119,
#  'brother': 120,
#  'brothers': 121,
#  'brought': 122,
#  'burnt': 123,
#  'busied': 124,
#  'business': 125,
#  'but': 126,
#  'by': 127,
#  'callous': 128,
#  'calm': 129,
#  'calmer': 130,
#  'came': 131,
#  'can': 132,
#  'candle': 133,
#  'cannot': 134,
#  'capable': 135,
#  'capacity': 136,
#  'care': 137,
#  'career': 138,
#  'catastrophe': 139,
#  'caught': 140,
#  'cause': 141,
#  'causes': 142,
#  'changes': 143,
#  'chapter': 144,
#  'character': 145,
#  'characters': 146,
#  'cheerful': 147,
#  'cheerfully': 148,
#  'chemical': 149,
#  'chemistry': 150,
#  'children': 151,
#  'chivalrous': 152,
#  'chivalry': 153,
#  'circumstances': 154,
#  'city': 155,
#  'clear': 156,
#  'clerval': 157,
#  'climbing': 158,
#  'clock': 159,
#  'closely': 160,
#  'closest': 161,
#  'cloud': 162,
#  'collected': 163,
#  'colour': 164,
#  'combined': 165,
#  'commence': 166,
#  'committed': 167,
#  'companion': 168,
#  'companionship': 169,
#  'completion': 170,
#  'complexion': 171,
#  'composed': 172,
#  'comprehensive': 173,
#  'conceive': 174,
#  'conceived': 175,
#  'concentrated': 176,
#  'conducive': 177,
#  'conduct': 178,
#  'confessed': 179,
#  'confident': 180,
#  'confirm': 181,
#  'confusion': 182,
#  'consequences': 183,
#  'considerable': 184,
#  'considered': 185,
#  'consolation': 186,
#  'constant': 187,
#  'constrained': 188,
#  'contemplated': 189,
#  'continual': 190,
#  'continually': 191,
#  'contrary': 192,
#  'contrast': 193,
#  'control': 194,
#  'convey': 195,
#  'convulsive': 196,
#  'cornelius': 197,
#  'could': 198,
#  'counsellors': 199,
#  'countenance': 200,
#  'country': 201,
#  'courage': 202,
#  'court': 203,
#  'cousin': 204,
#  'covered': 205,
#  'creations': 206,
#  'creature': 207,
#  'credit': 208,
#  'crime': 209,
#  'crowd': 210,
#  'cruel': 211,
#  'cultivated': 212,
#  'curiosity': 213,
#  'customs': 214,
#  'danger': 215,
#  'dangers': 216,
#  'dare': 217,
#  'date': 218,
#  'daughter': 219,
#  'day': 220,
#  'days': 221,
#  'deal': 222,
#  'dear': 223,
#  'dearly': 224,
#  'death': 225,
#  'deathbed': 226,
#  'debts': 227,
#  'decided': 228,
#  'declaration': 229,
#  'decline': 230,
#  'deeply': 231,
#  'delight': 232,
#  'delighted': 233,
#  'delineate': 234,
#  'departure': 235,
#  'depended': 236,
#  'deplored': 237,
#  'describe': 238,
#  'desert': 239,
#  'desired': 240,
#  'desirous': 241,
#  'devices': 242,
#  'devolved': 243,
#  'did': 244,
#  'difference': 245,
#  'dim': 246,
#  'disappeared': 247,
#  'discovered': 248,
#  'discoveries': 249,
#  'discovery': 250,
#  'discrimination': 251,
#  'dismally': 252,
#  'disposition': 253,
#  'dispute': 254,
#  'distance': 255,
#  'distant': 256,
#  'distemper': 257,
#  'distinguished': 258,
#  'disunion': 259,
#  'diversity': 260,
#  'divine': 261,
#  'do': 262,
#  'dogmatism': 263,
#  'drawn': 264,
#  'dreadfully': 265,
#  'dreary': 266,
#  'dressed': 267,
#  'drew': 268,
#  'dull': 269,
#  'dun': 270,
#  'during': 271,
#  'dusk': 272,
#  'each': 273,
#  'eager': 274,
#  'eagerly': 275,
#  'earliest': 276,
#  'early': 277,
#  'earnest': 278,
#  'easily': 279,
#  'eastern': 280,
#  'education': 281,
#  'elder': 282,
#  'eleven': 283,
#  'elizabeth': 284,
#  'emotions': 285,
#  'enchantment': 286,
#  'encountering': 287,
#  'end': 288,
#  'endeavour': 289,
#  'endeavoured': 290,
#  'endeavouring': 291,
#  'engaged': 292,
#  'engaging': 293,
#  'enormity': 294,
#  'enquired': 295,
#  'enter': 296,
#  'entered': 297,
#  'enterprise': 298,
#  'enticements': 299,
#  'entirely': 300,
#  'entreaties': 301,
#  'ernest': 302,
#  'esteem': 303,
#  'even': 304,
#  'evening': 305,
#  'event': 306,
#  'ever': 307,
#  'every': 308,
#  'evidently': 309,
#  'excited': 310,
#  'exculpated': 311,
#  'execrated': 312,
#  'expect': 313,
#  'expectation': 314,
#  'expected': 315,
#  'experienced': 316,
#  'expressed': 317,
#  'exquisitely': 318,
#  'extinguished': 319,
#  'exultation': 320,
#  'eye': 321,
#  'eyes': 322,
#  'facile': 323,
#  'false': 324,
#  'family': 325,
#  'fancy': 326,
#  'far': 327,
#  'farther': 328,
#  'fatal': 329,
#  'father': 330,
#  'favourite': 331,
#  'fear': 332,
#  'features': 333,
#  'feelings': 334,
#  'feet': 335,
#  'fell': 336,
#  'fellow': 337,
#  'fellows': 338,
#  'fervently': 339,
#  'fetter': 340,
#  'fever': 341,
#  'few': 342,
#  'figure': 343,
#  'filled': 344,
#  'find': 345,
#  'firmest': 346,
#  'first': 347,
#  'fix': 348,
#  'fixed': 349,
#  'flourishing': 350,
#  'flowing': 351,
#  'fluctuating': 352,
#  'following': 353,
#  'food': 354,
#  'for': 355,
#  'forbidden': 356,
#  'foreign': 357,
#  'form': 358,
#  'formed': 359,
#  'formerly': 360,
#  'fortitude': 361,
#  'found': 362,
#  'frankness': 363,
#  'friend': 364,
#  'friends': 365,
#  'friendship': 366,
#  'from': 367,
#  'full': 368,
#  'future': 369,
#  'gained': 370,
#  'gave': 371,
#  'gazed': 372,
#  'general': 373,
#  'geneva': 374,
#  'genevese': 375,
#  'genius': 376,
#  'gentleness': 377,
#  'get': 378,
#  'getting': 379,
#  'girl': 380,
#  'given': 381,
#  'glad': 382,
#  'gladness': 383,
#  'glimmer': 384,
#  'go': 385,
#  'god': 386,
#  'gone': 387,
#  'good': 388,
#  'grave': 389,
#  'great': 390,
#  'greatest': 391,
#  'griefs': 392,
#  'grieved': 393,
#  'guess': 394,
#  'guilt': 395,
#  'guiltlessness': 396,
#  'guilty': 397,
#  'had': 398,
#  'hair': 399,
#  'half': 400,
#  'hands': 401,
#  'handwriting': 402,
#  'happened': 403,
#  'happiness': 404,
#  'happy': 405,
#  'hard': 406,
#  'hardship': 407,
#  'harmony': 408,
#  'has': 409,
#  'have': 410,
#  'having': 411,
#  'he': 412,
#  'health': 413,
#  'heard': 414,
#  'heart': 415,
#  'heartfelt': 416,
#  'henry': 417,
#  'her': 418,
#  'heroes': 419,
#  'heroic': 420,
#  'herself': 421,
#  'hidden': 422,
#  'hide': 423,
#  'hills': 424,
#  'him': 425,
#  'himself': 426,
#  'his': 427,
#  'hitherto': 428,
#  'hold': 429,
#  'holy': 430,
#  'home': 431,
#  'honour': 432,
#  'honourable': 433,
#  'hope': 434,
#  'hoped': 435,
#  'hopes': 436,
#  'horrible': 437,
#  'horrid': 438,
#  'horror': 439,
#  'hours': 440,
#  'house': 441,
#  'how': 442,
#  'husband': 443,
#  'idea': 444,
#  'idler': 445,
#  'if': 446,
#  'ignominious': 447,
#  'ill': 448,
#  'illness': 449,
#  'illustrate': 450,
#  'imagination': 451,
#  'impatiently': 452,
#  'impossible': 453,
#  'improved': 454,
#  'improvement': 455,
#  'improvements': 456,
#  'imprudence': 457,
#  'in': 458,
#  'incident': 459,
#  'inconveniences': 460,
#  'indeed': 461,
#  'indefatigable': 462,
#  'indifferent': 463,
#  'indulge': 464,
#  'infallibly': 465,
#  'infamy': 466,
#  'infidels': 467,
#  'infinite': 468,
#  'inflict': 469,
#  'information': 470,
#  'infuse': 471,
#  'ingolstadt': 472,
#  'innocence': 473,
#  'inquirers': 474,
#  'inquiries': 475,
#  'instructions': 476,
#  'instruments': 477,
#  'integrity': 478,
#  'intelligence': 479,
#  'intense': 480,
#  'intimate': 481,
#  'into': 482,
#  'investigating': 483,
#  'is': 484,
#  'it': 485,
#  'its': 486,
#  'joined': 487,
#  'journey': 488,
#  'joy': 489,
#  'joys': 490,
#  'junior': 491,
#  'justice': 492,
#  'justine': 493,
#  'kind': 494,
#  'kindness': 495,
#  'king': 496,
#  'knew': 497,
#  'knightly': 498,
#  'know': 499,
#  'knowledge': 500,
#  'krempe': 501,
#  'laboratory': 502,
#  'lake': 503,
#  'last': 504,
#  'latter': 505,
#  'lawless': 506,
#  'laws': 507,
#  'lay': 508,
#  'league': 509,
#  'learn': 510,
#  'least': 511,
#  'lectures': 512,
#  'led': 513,
#  'less': 514,
#  'lessons': 515,
#  'letter': 516,
#  'letters': 517,
#  'life': 518,
#  'lifeless': 519,
#  'light': 520,
#  'limbs': 521,
#  'line': 522,
#  'lines': 523,
#  'lips': 524,
#  'little': 525,
#  'live': 526,
#  'lived': 527,
#  'lives': 528,
#  'living': 529,
#  'long': 530,
#  'longer': 531,
#  'look': 532,
#  'looks': 533,
#  'lost': 534,
#  'love': 535,
#  'loved': 536,
#  'lucerne': 537,
#  'lustrous': 538,
#  'luxuriances': 539,
#  'made': 540,
#  'madman': 541,
#  'magnificence': 542,
#  'magnificent': 543,
#  'majestic': 544,
#  'make': 545,
#  'malignity': 546,
#  'man': 547,
#  'manner': 548,
#  'manners': 549,
#  'many': 550,
#  'marriage': 551,
#  'marrying': 552,
#  'masquerades': 553,
#  'masters': 554,
#  'may': 555,
#  'me': 556,
#  'medical': 557,
#  'meeting': 558,
#  'memorable': 559,
#  'men': 560,
#  'menaced': 561,
#  'mentioning': 562,
#  'mercenary': 563,
#  'merchant': 564,
#  'merely': 565,
#  'merit': 566,
#  'might': 567,
#  'military': 568,
#  'mind': 569,
#  'minds': 570,
#  'minister': 571,
#  'mischances': 572,
#  'misery': 573,
#  'misfortune': 574,
#  'mockery': 575,
#  'moderate': 576,
#  'modern': 577,
#  'more': 578,
#  'morning': 579,
#  'most': 580,
#  'mother': 581,
#  'motion': 582,
#  'mountains': 583,
#  'mourning': 584,
#  'murder': 585,
#  'murdered': 586,
#  'muscles': 587,
#  'must': 588,
#  'my': 589,
#  'myself': 590,
#  'name': 591,
#  'native': 592,
#  'natural': 593,
#  'nature': 594,
#  'nearer': 595,
#  'nearly': 596,
#  'necessary': 597,
#  'need': 598,
#  'never': 599,
#  'news': 600,
#  'niece': 601,
#  'night': 602,
#  'no': 603,
#  'none': 604,
#  'nor': 605,
#  'not': 606,
#  'nothing': 607,
#  'november': 608,
#  'now': 609,
#  'numerous': 610,
#  'nurse': 611,
#  'object': 612,
#  'obliged': 613,
#  'obliterated': 614,
#  'oblivion': 615,
#  'occupation': 616,
#  'occupied': 617,
#  'occurred': 618,
#  'odious': 619,
#  'of': 620,
#  'often': 621,
#  'old': 622,
#  'omen': 623,
#  'on': 624,
#  'one': 625,
#  'only': 626,
#  'open': 627,
#  'or': 628,
#  'other': 629,
#  'others': 630,
#  'otherwise': 631,
#  'our': 632,
#  'out': 633,
#  'over': 634,
#  'own': 635,
#  'page': 636,
#  'paid': 637,
#  'pain': 638,
#  'pains': 639,
#  'panes': 640,
#  'parents': 641,
#  'part': 642,
#  'particularly': 643,
#  'passed': 644,
#  'path': 645,
#  'pattered': 646,
#  'pearly': 647,
#  'pedantry': 648,
#  'pen': 649,
#  'perform': 650,
#  'perhaps': 651,
#  'permit': 652,
#  'perpetually': 653,
#  'persuade': 654,
#  'persuading': 655,
#  'persuasions': 656,
#  'philosophy': 657,
#  'physiognomy': 658,
#  'place': 659,
#  'placed': 660,
#  'plainpalais': 661,
#  'playing': 662,
#  'plays': 663,
#  'pleased': 664,
#  'poets': 665,
#  'point': 666,
#  'poor': 667,
#  'possessed': 668,
#  'post': 669,
#  'poverty': 670,
#  'powers': 671,
#  'practice': 672,
#  'prepare': 673,
#  'presently': 674,
#  'preserver': 675,
#  'prevented': 676,
#  'pride': 677,
#  'principally': 678,
#  'probably': 679,
#  'proceeded': 680,
#  'procured': 681,
#  'profession': 682,
#  'professor': 683,
#  'professors': 684,
#  'proficiency': 685,
#  'prognosticated': 686,
#  'progress': 687,
#  'prolonged': 688,
#  'promised': 689,
#  'proof': 690,
#  'proportion': 691,
#  'prospect': 692,
#  'protracted': 693,
#  'proud': 694,
#  'public': 695,
#  'pursues': 696,
#  'pursuit': 697,
#  'qualities': 698,
#  'quickly': 699,
#  'quit': 700,
#  'quite': 701,
#  'rain': 702,
#  'rank': 703,
#  'rapid': 704,
#  'rapidly': 705,
#  'rapture': 706,
#  'rather': 707,
#  'ravings': 708,
#  'read': 709,
#  'real': 710,
#  'reassure': 711,
#  'recovered': 712,
#  'redeem': 713,
#  'refrain': 714,
#  'regret': 715,
#  'regretted': 716,
#  'relate': 717,
#  'relating': 718,
#  'remark': 719,
#  'remember': 720,
#  'render': 721,
#  'rendered': 722,
#  'republic': 723,
#  'repulsive': 724,
#  'reputation': 725,
#  'research': 726,
#  'resided': 727,
#  'residence': 728,
#  'resign': 729,
#  'resolved': 730,
#  'respected': 731,
#  'rest': 732,
#  'rested': 733,
#  'restrained': 734,
#  'result': 735,
#  'retreat': 736,
#  'retreated': 737,
#  'return': 738,
#  'returning': 739,
#  'returns': 740,
#  'romance': 741,
#  'roncesvalles': 742,
#  'round': 743,
#  'rowing': 744,
#  'run': 745,
#  'sad': 746,
#  'said': 747,
#  'sake': 748,
#  'same': 749,
#  'satisfied': 750,
#  'saved': 751,
#  'saw': 752,
#  'say': 753,
#  'scarcely': 754,
#  'scarlet': 755,
#  'scenes': 756,
#  'school': 757,
#  'schools': 758,
#  'science': 759,
#  'scientific': 760,
#  'scope': 761,
#  'seasons': 762,
#  'seat': 763,
#  'seated': 764,
#  'seclusion': 765,
#  'second': 766,
#  'secret': 767,
#  'see': 768,
#  'seek': 769,
#  'seemed': 770,
#  'seen': 771,
#  'selected': 772,
#  'sensations': 773,
#  'sense': 774,
#  'sepulchre': 775,
#  'serene': 776,
#  'serious': 777,
#  'service': 778,
#  'set': 779,
#  'seven': 780,
#  'seventeen': 781,
#  'several': 782,
#  'severe': 783,
#  'shall': 784,
#  'shapes': 785,
#  'she': 786,
#  'shed': 787,
#  'shore': 788,
#  'should': 789,
#  'shrivelled': 790,
#  'sickbed': 791,
#  'sickened': 792,
#  'silence': 793,
#  'singular': 794,
#  'situations': 795,
#  'sixteen': 796,
#  'skims': 797,
#  'skin': 798,
#  'sly': 799,
#  'smile': 800,
#  'smiling': 801,
#  'smitten': 802,
#  'smoothed': 803,
#  'so': 804,
#  'sockets': 805,
#  'sole': 806,
#  'solely': 807,
#  'solemnity': 808,
#  'some': 809,
#  'son': 810,
#  'songs': 811,
#  'soon': 812,
#  'sorrowful': 813,
#  'sought': 814,
#  'soul': 815,
#  'sound': 816,
#  'spark': 817,
#  'species': 818,
#  'spectators': 819,
#  'spent': 820,
#  'spirit': 821,
#  'stars': 822,
#  'state': 823,
#  'stay': 824,
#  'straight': 825,
#  'strangers': 826,
#  'strength': 827,
#  'student': 828,
#  'students': 829,
#  'studies': 830,
#  'study': 831,
#  'subjects': 832,
#  'sublime': 833,
#  'subsisted': 834,
#  'such': 835,
#  'suffered': 836,
#  'sufficient': 837,
#  'summers': 838,
#  'supply': 839,
#  'supposed': 840,
#  'surprise': 841,
#  'surrounded': 842,
#  'swiss': 843,
#  'symptoms': 844,
#  'syndics': 845,
#  'table': 846,
#  'taken': 847,
#  'tale': 848,
#  'talent': 849,
#  'task': 850,
#  'tear': 851,
#  'tears': 852,
#  'teeth': 853,
#  'temper': 854,
#  'tempest': 855,
#  'tempted': 856,
#  'term': 857,
#  'than': 858,
#  'that': 859,
#  'the': 860,
#  'their': 861,
#  'them': 862,
#  'themselves': 863,
#  'then': 864,
#  'theory': 865,
#  'there': 866,
#  'therefore': 867,
#  'these': 868,
#  'they': 869,
#  'thing': 870,
#  'things': 871,
#  'third': 872,
#  'thirst': 873,
#  'this': 874,
#  'those': 875,
#  'thought': 876,
#  'thoughts': 877,
#  'thousand': 878,
#  'thousands': 879,
#  'threw': 880,
#  'through': 881,
#  'thursday': 882,
#  'tidings': 883,
#  'time': 884,
#  'times': 885,
#  'tinged': 886,
#  'to': 887,
#  'together': 888,
#  'toils': 889,
#  'torture': 890,
#  'town': 891,
#  'train': 892,
#  'tranquil': 893,
#  'tranquillity': 894,
#  'tremble': 895,
#  'trial': 896,
#  'tried': 897,
#  'triumphed': 898,
#  'true': 899,
#  'truest': 900,
#  'turbulence': 901,
#  'two': 902,
#  'unbending': 903,
#  'uncertain': 904,
#  'uncle': 905,
#  'undertaking': 906,
#  'unfolded': 907,
#  'unfortunate': 908,
#  'union': 909,
#  'united': 910,
#  'university': 911,
#  'unknown': 912,
#  'unless': 913,
#  'until': 914,
#  'up': 915,
#  'upon': 916,
#  'urged': 917,
#  'us': 918,
#  'usual': 919,
#  'utter': 920,
#  'vainly': 921,
#  'valuable': 922,
#  'variety': 923,
#  'very': 924,
#  'victor': 925,
#  'vigorous': 926,
#  'visit': 927,
#  'waited': 928,
#  'waldman': 929,
#  'walk': 930,
#  'wandering': 931,
#  'warm': 932,
#  'was': 933,
#  'watchful': 934,
#  'watery': 935,
#  'ways': 936,
#  'we': 937,
#  'welcome': 938,
#  'well': 939,
#  'went': 940,
#  'were': 941,
#  'what': 942,
#  'when': 943,
#  'where': 944,
#  'whether': 945,
#  'which': 946,
#  'while': 947,
#  'whilst': 948,
#  'white': 949,
#  'whiteness': 950,
#  'who': 951,
#  'whole': 952,
#  'whom': 953,
#  'whose': 954,
#  'will': 955,
#  'william': 956,
#  'winter': 957,
#  'wish': 958,
#  'wishes': 959,
#  'with': 960,
#  'witnesses': 961,
#  'woeful': 962,
#  'women': 963,
#  'wonder': 964,
#  'wondrous': 965,
#  'word': 966,
#  'words': 967,
#  'work': 968,
#  'worked': 969,
#  'works': 970,
#  'world': 971,
#  'worst': 972,
#  'worthy': 973,
#  'would': 974,
#  'wrapped': 975,
#  'wretch': 976,
#  'wretched': 977,
#  'wretchedness': 978,
#  'write': 979,
#  'writes': 980,
#  'written': 981,
#  'year': 982,
#  'years': 983,
#  'yellow': 984,
#  'yet': 985,
#  'yield': 986,
#  'yielded': 987,
#  'you': 988,
#  'younger': 989,
#  'your': 990}

# %%
tfidf_vector.shape
# Out:
# (8, 991)

# %%
tfidf_vectorizer.idf_
# Out:
# array([2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.58778666, 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 1.40546511,
#        2.5040774 , 1.        , 2.5040774 , 2.09861229, 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.81093022, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 1.58778666,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.11778304, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.25131443, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.40546511, 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.09861229, 1.81093022,
#        1.40546511, 2.5040774 , 1.58778666, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.58778666, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.11778304, 1.25131443, 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 1.58778666, 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 1.        ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.58778666, 2.5040774 ,
#        2.09861229, 1.58778666, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        1.81093022, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.81093022, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 1.58778666,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.81093022, 2.09861229, 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        1.58778666, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.81093022, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.81093022, 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.11778304, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.81093022, 2.5040774 , 2.09861229,
#        1.81093022, 2.09861229, 1.40546511, 1.81093022, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.11778304, 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.58778666, 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.40546511, 2.5040774 , 1.40546511, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.09861229, 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.81093022, 2.5040774 , 1.40546511, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.58778666, 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 1.        , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.81093022, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.58778666, 2.5040774 , 1.40546511,
#        1.        , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.09861229, 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.40546511, 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.09861229, 2.5040774 , 2.09861229, 2.5040774 ,
#        2.09861229, 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.81093022, 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        1.81093022, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 1.25131443, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.58778666, 2.09861229,
#        1.81093022, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 1.        ,
#        1.58778666, 2.5040774 , 1.81093022, 2.5040774 , 2.09861229,
#        2.5040774 , 2.09861229, 2.09861229, 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.81093022, 2.5040774 ,
#        2.09861229, 1.11778304, 2.5040774 , 2.5040774 , 1.58778666,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.        , 2.09861229, 2.5040774 , 2.5040774 , 1.11778304,
#        1.25131443, 2.09861229, 2.09861229, 1.81093022, 1.81093022,
#        2.5040774 , 2.5040774 , 1.58778666, 2.09861229, 1.81093022,
#        2.09861229, 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 1.58778666,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.09861229,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.09861229, 2.5040774 , 2.09861229, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.81093022, 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.09861229, 2.5040774 , 2.09861229, 2.5040774 , 2.09861229,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.81093022, 1.        ,
#        1.        , 2.5040774 , 1.40546511, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 1.81093022, 1.58778666, 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 1.25131443,
#        2.09861229, 1.58778666, 2.5040774 , 2.09861229, 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 1.        , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.09861229, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.09861229,
#        2.5040774 , 2.5040774 , 1.81093022, 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.09861229, 2.5040774 , 2.5040774 , 1.58778666,
#        1.81093022, 2.09861229, 2.5040774 , 1.58778666, 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.11778304, 2.5040774 ,
#        2.5040774 , 2.5040774 , 1.58778666, 2.5040774 , 2.09861229,
#        2.09861229, 1.25131443, 2.5040774 , 1.40546511, 2.09861229,
#        2.5040774 , 1.11778304, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.25131443, 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.09861229, 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        1.        , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 , 2.5040774 ,
#        2.5040774 , 1.81093022, 2.5040774 , 2.5040774 , 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 2.09861229, 1.81093022,
#        2.5040774 , 2.5040774 , 2.5040774 , 1.81093022, 2.5040774 ,
#        1.81093022, 2.5040774 , 2.5040774 , 1.58778666, 2.09861229,
#        1.81093022])

# %%
dict(zip(tfidf_vectorizer.get_feature_names(), tfidf_vectorizer.idf_))
# Out:
# {'7th': 2.504077396776274,
#  '_campagne_': 2.504077396776274,
#  'able': 2.504077396776274,
#  'absence': 2.504077396776274,
#  'absent': 2.09861228866811,
#  'abstruse': 2.504077396776274,
#  'accompanied': 2.09861228866811,
#  'accomplishment': 2.504077396776274,
#  'accordingly': 2.504077396776274,
#  'account': 2.09861228866811,
#  'acquaintance': 2.504077396776274,
#  'acquainted': 2.09861228866811,
#  'act': 2.504077396776274,
#  'activity': 2.504077396776274,
#  'adduced': 2.504077396776274,
#  'admiration': 2.09861228866811,
#  'adventure': 2.504077396776274,
#  'aerial': 2.504077396776274,
#  'affairs': 2.504077396776274,
#  'affection': 1.8109302162163288,
#  'afterwards': 2.504077396776274,
#  'again': 2.504077396776274,
#  'against': 2.504077396776274,
#  'age': 2.504077396776274,
#  'ages': 2.504077396776274,
#  'aggravation': 2.504077396776274,
#  'agitated': 2.504077396776274,
#  'agony': 2.504077396776274,
#  'agrippa': 2.504077396776274,
#  'air': 2.09861228866811,
#  'akin': 2.504077396776274,
#  'alarming': 2.504077396776274,
#  'alas': 2.504077396776274,
#  'all': 1.587786664902119,
#  'almost': 2.504077396776274,
#  'alpine': 2.504077396776274,
#  'already': 2.09861228866811,
#  'also': 2.504077396776274,
#  'although': 2.504077396776274,
#  'always': 2.504077396776274,
#  'am': 2.09861228866811,
#  'among': 2.504077396776274,
#  'amounted': 2.504077396776274,
#  'ample': 2.504077396776274,
#  'an': 1.4054651081081644,
#  'ancestors': 2.504077396776274,
#  'and': 1.0,
#  'another': 2.504077396776274,
#  'anxiety': 2.09861228866811,
#  'any': 2.09861228866811,
#  'appearance': 2.504077396776274,
#  'appearances': 2.504077396776274,
#  'appeared': 2.504077396776274,
#  'application': 1.8109302162163288,
#  'applied': 2.504077396776274,
#  'apprehension': 2.504077396776274,
#  'apprehensions': 2.504077396776274,
#  'ardent': 2.504077396776274,
#  'ardour': 2.09861228866811,
#  'are': 1.587786664902119,
#  'arguments': 2.504077396776274,
#  'around': 2.504077396776274,
#  'arrive': 2.09861228866811,
#  'arrived': 2.504077396776274,
#  'arteries': 2.504077396776274,
#  'arthur': 2.504077396776274,
#  'as': 1.1177830356563834,
#  'ascribed': 2.504077396776274,
#  'asked': 2.504077396776274,
#  'asks': 2.504077396776274,
#  'assistance': 2.504077396776274,
#  'assured': 2.504077396776274,
#  'astonishment': 2.504077396776274,
#  'at': 1.251314428280906,
#  'attach': 2.504077396776274,
#  'attained': 2.504077396776274,
#  'attainment': 2.504077396776274,
#  'attend': 2.504077396776274,
#  'attendants': 2.504077396776274,
#  'attended': 2.09861228866811,
#  'attending': 2.09861228866811,
#  'attention': 2.504077396776274,
#  'attentions': 2.504077396776274,
#  'attest': 2.504077396776274,
#  'avoid': 2.504077396776274,
#  'away': 2.504077396776274,
#  'babe': 2.504077396776274,
#  'banished': 2.504077396776274,
#  'be': 1.4054651081081644,
#  'bear': 2.504077396776274,
#  'beaufort': 2.504077396776274,
#  'beautiful': 2.09861228866811,
#  'beauty': 2.504077396776274,
#  'became': 2.09861228866811,
#  'become': 1.8109302162163288,
#  'been': 1.4054651081081644,
#  'befitting': 2.504077396776274,
#  'before': 1.587786664902119,
#  'began': 2.504077396776274,
#  'begin': 2.504077396776274,
#  'beheld': 2.504077396776274,
#  'behold': 2.504077396776274,
#  'being': 1.587786664902119,
#  'beings': 2.504077396776274,
#  'beloved': 2.504077396776274,
#  'belrive': 2.504077396776274,
#  'beneath': 2.504077396776274,
#  'benevolent': 2.504077396776274,
#  'benignity': 2.504077396776274,
#  'best': 2.504077396776274,
#  'better': 2.504077396776274,
#  'birth': 2.09861228866811,
#  'bitterly': 2.504077396776274,
#  'black': 2.504077396776274,
#  'blood': 2.504077396776274,
#  'bonds': 2.504077396776274,
#  'books': 2.504077396776274,
#  'boy': 2.504077396776274,
#  'breathed': 2.504077396776274,
#  'bring': 2.504077396776274,
#  'brother': 2.09861228866811,
#  'brothers': 2.504077396776274,
#  'brought': 2.504077396776274,
#  'burnt': 2.504077396776274,
#  'busied': 2.504077396776274,
#  'business': 2.504077396776274,
#  'but': 1.1177830356563834,
#  'by': 1.251314428280906,
#  'callous': 2.504077396776274,
#  'calm': 1.8109302162163288,
#  'calmer': 2.504077396776274,
#  'came': 2.504077396776274,
#  'can': 1.587786664902119,
#  'candle': 2.504077396776274,
#  'cannot': 1.8109302162163288,
#  'capable': 2.504077396776274,
#  'capacity': 2.504077396776274,
#  'care': 2.09861228866811,
#  'career': 2.504077396776274,
#  'catastrophe': 2.504077396776274,
#  'caught': 2.504077396776274,
#  'cause': 2.504077396776274,
#  'causes': 2.504077396776274,
#  'changes': 2.504077396776274,
#  'chapter': 1.0,
#  'character': 2.504077396776274,
#  'characters': 2.504077396776274,
#  'cheerful': 2.504077396776274,
#  'cheerfully': 2.504077396776274,
#  'chemical': 2.504077396776274,
#  'chemistry': 2.504077396776274,
#  'children': 2.504077396776274,
#  'chivalrous': 2.504077396776274,
#  'chivalry': 2.504077396776274,
#  'circumstances': 2.504077396776274,
#  'city': 2.504077396776274,
#  'clear': 2.504077396776274,
#  'clerval': 2.09861228866811,
#  'climbing': 2.504077396776274,
#  'clock': 2.504077396776274,
#  'closely': 2.504077396776274,
#  'closest': 2.504077396776274,
#  'cloud': 2.504077396776274,
#  'collected': 2.504077396776274,
#  'colour': 2.504077396776274,
#  'combined': 2.504077396776274,
#  'commence': 2.504077396776274,
#  'committed': 2.504077396776274,
#  'companion': 2.504077396776274,
#  'companionship': 2.504077396776274,
#  'completion': 2.504077396776274,
#  'complexion': 2.504077396776274,
#  'composed': 2.504077396776274,
#  'comprehensive': 2.504077396776274,
#  'conceive': 2.504077396776274,
#  'conceived': 2.504077396776274,
#  'concentrated': 2.504077396776274,
#  'conducive': 2.504077396776274,
#  'conduct': 2.504077396776274,
#  'confessed': 2.504077396776274,
#  'confident': 2.504077396776274,
#  'confirm': 2.504077396776274,
#  'confusion': 2.504077396776274,
#  'consequences': 2.504077396776274,
#  'considerable': 2.504077396776274,
#  'considered': 2.504077396776274,
#  'consolation': 2.504077396776274,
#  'constant': 2.504077396776274,
#  'constrained': 2.504077396776274,
#  'contemplated': 2.504077396776274,
#  'continual': 2.504077396776274,
#  'continually': 2.504077396776274,
#  'contrary': 2.504077396776274,
#  'contrast': 2.09861228866811,
#  'control': 2.504077396776274,
#  'convey': 2.504077396776274,
#  'convulsive': 2.504077396776274,
#  'cornelius': 2.504077396776274,
#  'could': 1.587786664902119,
#  'counsellors': 2.504077396776274,
#  'countenance': 2.09861228866811,
#  'country': 1.587786664902119,
#  'courage': 2.504077396776274,
#  'court': 2.504077396776274,
#  'cousin': 2.504077396776274,
#  'covered': 2.504077396776274,
#  'creations': 2.504077396776274,
#  'creature': 2.504077396776274,
#  'credit': 2.504077396776274,
#  'crime': 2.504077396776274,
#  'crowd': 2.504077396776274,
#  'cruel': 2.504077396776274,
#  'cultivated': 2.504077396776274,
#  'curiosity': 2.09861228866811,
#  'customs': 2.504077396776274,
#  'danger': 2.09861228866811,
#  'dangers': 2.504077396776274,
#  'dare': 2.504077396776274,
#  'date': 2.09861228866811,
#  'daughter': 2.504077396776274,
#  'day': 1.8109302162163288,
#  'days': 2.504077396776274,
#  'deal': 2.504077396776274,
#  'dear': 2.504077396776274,
#  'dearly': 2.504077396776274,
#  'death': 2.09861228866811,
#  'deathbed': 2.504077396776274,
#  'debts': 2.504077396776274,
#  'decided': 2.504077396776274,
#  'declaration': 2.504077396776274,
#  'decline': 2.504077396776274,
#  'deeply': 2.09861228866811,
#  'delight': 2.504077396776274,
#  'delighted': 2.504077396776274,
#  'delineate': 2.504077396776274,
#  'departure': 2.504077396776274,
#  'depended': 2.504077396776274,
#  'deplored': 2.504077396776274,
#  'describe': 2.504077396776274,
#  'desert': 2.504077396776274,
#  'desired': 2.504077396776274,
#  'desirous': 2.504077396776274,
#  'devices': 2.504077396776274,
#  'devolved': 2.504077396776274,
#  'did': 1.8109302162163288,
#  'difference': 2.504077396776274,
#  'dim': 2.504077396776274,
#  'disappeared': 2.504077396776274,
#  'discovered': 2.09861228866811,
#  'discoveries': 2.504077396776274,
#  'discovery': 2.504077396776274,
#  'discrimination': 2.504077396776274,
#  'dismally': 2.504077396776274,
#  'disposition': 2.09861228866811,
#  'dispute': 2.504077396776274,
#  'distance': 2.504077396776274,
#  'distant': 2.504077396776274,
#  'distemper': 2.504077396776274,
#  'distinguished': 2.504077396776274,
#  'disunion': 2.504077396776274,
#  'diversity': 2.504077396776274,
#  'divine': 2.504077396776274,
#  'do': 2.504077396776274,
#  'dogmatism': 2.504077396776274,
#  'drawn': 2.504077396776274,
#  'dreadfully': 2.504077396776274,
#  'dreary': 2.504077396776274,
#  'dressed': 2.504077396776274,
#  'drew': 2.504077396776274,
#  'dull': 2.504077396776274,
#  'dun': 2.504077396776274,
#  'during': 1.8109302162163288,
#  'dusk': 2.504077396776274,
#  'each': 2.504077396776274,
#  'eager': 2.504077396776274,
#  'eagerly': 2.504077396776274,
#  'earliest': 2.504077396776274,
#  'early': 2.09861228866811,
#  'earnest': 2.504077396776274,
#  'easily': 2.504077396776274,
#  'eastern': 2.504077396776274,
#  'education': 2.504077396776274,
#  'elder': 2.504077396776274,
#  'eleven': 2.504077396776274,
#  'elizabeth': 2.09861228866811,
#  'emotions': 2.504077396776274,
#  'enchantment': 2.504077396776274,
#  'encountering': 2.504077396776274,
#  'end': 2.504077396776274,
#  'endeavour': 2.504077396776274,
#  'endeavoured': 2.504077396776274,
#  'endeavouring': 2.504077396776274,
#  'engaged': 2.504077396776274,
#  'engaging': 2.504077396776274,
#  'enormity': 2.504077396776274,
#  'enquired': 2.504077396776274,
#  'enter': 2.09861228866811,
#  'entered': 2.504077396776274,
#  'enterprise': 2.504077396776274,
#  'enticements': 2.504077396776274,
#  'entirely': 2.504077396776274,
#  'entreaties': 2.504077396776274,
#  'ernest': 2.09861228866811,
#  'esteem': 2.504077396776274,
#  'even': 1.587786664902119,
#  'evening': 2.504077396776274,
#  'event': 2.504077396776274,
#  'ever': 2.504077396776274,
#  'every': 2.09861228866811,
#  'evidently': 2.504077396776274,
#  'excited': 2.504077396776274,
#  'exculpated': 2.504077396776274,
#  'execrated': 2.504077396776274,
#  'expect': 2.504077396776274,
#  'expectation': 2.504077396776274,
#  'expected': 2.504077396776274,
#  'experienced': 2.504077396776274,
#  'expressed': 2.504077396776274,
#  'exquisitely': 2.504077396776274,
#  'extinguished': 2.504077396776274,
#  'exultation': 2.504077396776274,
#  'eye': 1.8109302162163288,
#  'eyes': 2.09861228866811,
#  'facile': 2.504077396776274,
#  'false': 2.504077396776274,
#  'family': 2.09861228866811,
#  'fancy': 2.504077396776274,
#  'far': 2.09861228866811,
#  'farther': 2.504077396776274,
#  'fatal': 2.504077396776274,
#  'father': 1.587786664902119,
#  'favourite': 2.504077396776274,
#  'fear': 2.504077396776274,
#  'features': 2.504077396776274,
#  'feelings': 2.504077396776274,
#  'feet': 2.504077396776274,
#  'fell': 2.504077396776274,
#  'fellow': 2.504077396776274,
#  'fellows': 2.504077396776274,
#  'fervently': 2.504077396776274,
#  'fetter': 2.504077396776274,
#  'fever': 2.504077396776274,
#  'few': 1.8109302162163288,
#  'figure': 2.504077396776274,
#  'filled': 2.504077396776274,
#  'find': 2.504077396776274,
#  'firmest': 2.504077396776274,
#  'first': 1.8109302162163288,
#  'fix': 2.504077396776274,
#  'fixed': 2.09861228866811,
#  'flourishing': 2.504077396776274,
#  'flowing': 2.504077396776274,
#  'fluctuating': 2.504077396776274,
#  'following': 2.504077396776274,
#  'food': 2.504077396776274,
#  'for': 1.1177830356563834,
#  'forbidden': 2.504077396776274,
#  'foreign': 2.504077396776274,
#  'form': 2.504077396776274,
#  'formed': 2.504077396776274,
#  'formerly': 2.504077396776274,
#  'fortitude': 2.504077396776274,
#  'found': 1.8109302162163288,
#  'frankness': 2.504077396776274,
#  'friend': 2.09861228866811,
#  'friends': 1.8109302162163288,
#  'friendship': 2.09861228866811,
#  'from': 1.4054651081081644,
#  'full': 1.8109302162163288,
#  'future': 2.504077396776274,
#  'gained': 2.504077396776274,
#  'gave': 2.504077396776274,
#  'gazed': 2.504077396776274,
#  'general': 2.504077396776274,
#  'geneva': 1.8109302162163288,
#  'genevese': 2.504077396776274,
#  'genius': 2.504077396776274,
#  'gentleness': 2.504077396776274,
#  'get': 2.504077396776274,
#  'getting': 2.504077396776274,
#  'girl': 2.504077396776274,
#  'given': 2.504077396776274,
#  'glad': 2.504077396776274,
#  'gladness': 2.504077396776274,
#  'glimmer': 2.504077396776274,
#  'go': 2.504077396776274,
#  'god': 2.504077396776274,
#  'gone': 2.09861228866811,
#  'good': 2.504077396776274,
#  'grave': 2.504077396776274,
#  'great': 2.09861228866811,
#  'greatest': 2.504077396776274,
#  'griefs': 2.504077396776274,
#  'grieved': 2.504077396776274,
#  'guess': 2.504077396776274,
#  'guilt': 2.504077396776274,
#  'guiltlessness': 2.504077396776274,
#  'guilty': 2.504077396776274,
#  'had': 1.1177830356563834,
#  'hair': 2.504077396776274,
#  'half': 2.504077396776274,
#  'hands': 2.09861228866811,
#  'handwriting': 2.504077396776274,
#  'happened': 2.504077396776274,
#  'happiness': 2.504077396776274,
#  'happy': 1.587786664902119,
#  'hard': 2.09861228866811,
#  'hardship': 2.504077396776274,
#  'harmony': 2.504077396776274,
#  'has': 2.504077396776274,
#  'have': 1.4054651081081644,
#  'having': 2.504077396776274,
#  'he': 1.4054651081081644,
#  'health': 2.504077396776274,
#  'heard': 2.504077396776274,
#  'heart': 2.504077396776274,
#  'heartfelt': 2.504077396776274,
#  'henry': 2.09861228866811,
#  'her': 2.09861228866811,
#  'heroes': 2.504077396776274,
#  'heroic': 2.504077396776274,
#  'herself': 2.09861228866811,
#  'hidden': 2.504077396776274,
#  'hide': 2.504077396776274,
#  'hills': 2.504077396776274,
#  'him': 1.8109302162163288,
#  'himself': 2.504077396776274,
#  'his': 1.4054651081081644,
#  'hitherto': 2.504077396776274,
#  'hold': 2.504077396776274,
#  'holy': 2.504077396776274,
#  'home': 2.09861228866811,
#  'honour': 2.504077396776274,
#  'honourable': 2.504077396776274,
#  'hope': 1.8109302162163288,
#  'hoped': 2.504077396776274,
#  'hopes': 2.504077396776274,
#  'horrible': 2.504077396776274,
#  'horrid': 2.504077396776274,
#  'horror': 2.504077396776274,
#  'hours': 2.504077396776274,
#  'house': 2.504077396776274,
#  'how': 1.587786664902119,
#  'husband': 2.504077396776274,
#  'idea': 2.09861228866811,
#  'idler': 2.504077396776274,
#  'if': 2.504077396776274,
#  'ignominious': 2.504077396776274,
#  'ill': 2.504077396776274,
#  'illness': 2.504077396776274,
#  'illustrate': 2.504077396776274,
#  'imagination': 2.504077396776274,
#  'impatiently': 2.504077396776274,
#  'impossible': 2.504077396776274,
#  'improved': 2.504077396776274,
#  'improvement': 2.09861228866811,
#  'improvements': 2.504077396776274,
#  'imprudence': 2.504077396776274,
#  'in': 1.0,
#  'incident': 2.504077396776274,
#  'inconveniences': 2.504077396776274,
#  'indeed': 2.09861228866811,
#  'indefatigable': 2.504077396776274,
#  'indifferent': 2.504077396776274,
#  'indulge': 2.504077396776274,
#  'infallibly': 2.504077396776274,
#  'infamy': 2.504077396776274,
#  'infidels': 2.504077396776274,
#  'infinite': 2.504077396776274,
#  'inflict': 2.504077396776274,
#  'information': 2.504077396776274,
#  'infuse': 2.504077396776274,
#  'ingolstadt': 1.8109302162163288,
#  'innocence': 2.504077396776274,
#  'inquirers': 2.504077396776274,
#  'inquiries': 2.504077396776274,
#  'instructions': 2.504077396776274,
#  'instruments': 2.09861228866811,
#  'integrity': 2.504077396776274,
#  'intelligence': 2.504077396776274,
#  'intense': 2.504077396776274,
#  'intimate': 2.504077396776274,
#  'into': 1.587786664902119,
#  'investigating': 2.504077396776274,
#  'is': 1.4054651081081644,
#  'it': 1.0,
#  'its': 2.09861228866811,
#  'joined': 2.504077396776274,
#  'journey': 2.504077396776274,
#  'joy': 2.504077396776274,
#  'joys': 2.504077396776274,
#  'junior': 2.504077396776274,
#  'justice': 2.504077396776274,
#  'justine': 2.504077396776274,
#  'kind': 2.504077396776274,
#  'kindness': 2.09861228866811,
#  'king': 2.504077396776274,
#  'knew': 2.504077396776274,
#  'knightly': 2.504077396776274,
#  'know': 2.09861228866811,
#  'knowledge': 2.09861228866811,
#  'krempe': 2.504077396776274,
#  'laboratory': 2.504077396776274,
#  'lake': 2.09861228866811,
#  'last': 2.504077396776274,
#  'latter': 2.504077396776274,
#  'lawless': 2.504077396776274,
#  'laws': 2.504077396776274,
#  'lay': 2.504077396776274,
#  'league': 2.504077396776274,
#  'learn': 2.504077396776274,
#  'least': 2.504077396776274,
#  'lectures': 2.504077396776274,
#  'led': 2.504077396776274,
#  'less': 2.504077396776274,
#  'lessons': 2.504077396776274,
#  'letter': 2.504077396776274,
#  'letters': 2.504077396776274,
#  'life': 1.4054651081081644,
#  'lifeless': 2.504077396776274,
#  'light': 2.09861228866811,
#  'limbs': 2.504077396776274,
#  'line': 2.504077396776274,
#  'lines': 2.504077396776274,
#  'lips': 2.504077396776274,
#  'little': 2.504077396776274,
#  'live': 2.504077396776274,
#  'lived': 2.504077396776274,
#  'lives': 2.504077396776274,
#  'living': 2.504077396776274,
#  'long': 2.09861228866811,
#  'longer': 2.09861228866811,
#  'look': 2.504077396776274,
#  'looks': 2.09861228866811,
#  'lost': 2.504077396776274,
#  'love': 2.09861228866811,
#  'loved': 2.09861228866811,
#  'lucerne': 2.504077396776274,
#  'lustrous': 2.504077396776274,
#  'luxuriances': 2.504077396776274,
#  'made': 2.09861228866811,
#  'madman': 2.504077396776274,
#  'magnificence': 2.504077396776274,
#  'magnificent': 2.504077396776274,
#  'majestic': 2.504077396776274,
#  'make': 1.8109302162163288,
#  'malignity': 2.504077396776274,
#  'man': 2.504077396776274,
#  'manner': 2.09861228866811,
#  'manners': 2.504077396776274,
#  'many': 1.8109302162163288,
#  'marriage': 2.504077396776274,
#  'marrying': 2.504077396776274,
#  'masquerades': 2.504077396776274,
#  'masters': 2.504077396776274,
#  'may': 2.09861228866811,
#  'me': 1.251314428280906,
#  'medical': 2.504077396776274,
#  'meeting': 2.504077396776274,
#  'memorable': 2.504077396776274,
#  'men': 2.504077396776274,
#  'menaced': 2.504077396776274,
#  'mentioning': 2.504077396776274,
#  'mercenary': 2.504077396776274,
#  'merchant': 2.09861228866811,
#  'merely': 2.504077396776274,
#  'merit': 2.504077396776274,
#  'might': 2.09861228866811,
#  'military': 2.504077396776274,
#  'mind': 2.09861228866811,
#  'minds': 2.504077396776274,
#  'minister': 2.504077396776274,
#  'mischances': 2.504077396776274,
#  'misery': 2.504077396776274,
#  'misfortune': 2.09861228866811,
#  'mockery': 2.504077396776274,
#  'moderate': 2.504077396776274,
#  'modern': 2.504077396776274,
#  'more': 1.587786664902119,
#  'morning': 2.09861228866811,
#  'most': 1.8109302162163288,
#  'mother': 2.504077396776274,
#  'motion': 2.504077396776274,
#  'mountains': 2.504077396776274,
#  'mourning': 2.504077396776274,
#  'murder': 2.504077396776274,
#  'murdered': 2.504077396776274,
#  'muscles': 2.504077396776274,
#  'must': 2.09861228866811,
#  'my': 1.0,
#  'myself': 1.587786664902119,
#  'name': 2.504077396776274,
#  'native': 1.8109302162163288,
#  'natural': 2.504077396776274,
#  'nature': 2.09861228866811,
#  'nearer': 2.504077396776274,
#  'nearly': 2.09861228866811,
#  'necessary': 2.09861228866811,
#  'need': 2.504077396776274,
#  'never': 2.09861228866811,
#  'news': 2.504077396776274,
#  'niece': 2.504077396776274,
#  'night': 2.504077396776274,
#  'no': 1.8109302162163288,
#  'none': 2.504077396776274,
#  'nor': 2.09861228866811,
#  'not': 1.1177830356563834,
#  'nothing': 2.504077396776274,
#  'november': 2.504077396776274,
#  'now': 1.587786664902119,
#  'numerous': 2.504077396776274,
#  'nurse': 2.504077396776274,
#  'object': 2.504077396776274,
#  'obliged': 2.504077396776274,
#  'obliterated': 2.504077396776274,
#  'oblivion': 2.504077396776274,
#  'occupation': 2.504077396776274,
#  'occupied': 2.504077396776274,
#  'occurred': 2.504077396776274,
#  'odious': 2.504077396776274,
#  'of': 1.0,
#  'often': 2.09861228866811,
#  'old': 2.504077396776274,
#  'omen': 2.504077396776274,
#  'on': 1.1177830356563834,
#  'one': 1.251314428280906,
#  'only': 2.09861228866811,
#  'open': 2.09861228866811,
#  'or': 1.8109302162163288,
#  'other': 1.8109302162163288,
#  'others': 2.504077396776274,
#  'otherwise': 2.504077396776274,
#  'our': 1.587786664902119,
#  'out': 2.09861228866811,
#  'over': 1.8109302162163288,
#  'own': 2.09861228866811,
#  'page': 2.504077396776274,
#  'paid': 2.09861228866811,
#  'pain': 2.504077396776274,
#  'pains': 2.504077396776274,
#  'panes': 2.504077396776274,
#  'parents': 2.09861228866811,
#  'part': 2.504077396776274,
#  'particularly': 2.504077396776274,
#  'passed': 1.587786664902119,
#  'path': 2.504077396776274,
#  'pattered': 2.504077396776274,
#  'pearly': 2.504077396776274,
#  'pedantry': 2.504077396776274,
#  'pen': 2.504077396776274,
#  'perform': 2.504077396776274,
#  'perhaps': 2.504077396776274,
#  'permit': 2.504077396776274,
#  'perpetually': 2.504077396776274,
#  'persuade': 2.504077396776274,
#  'persuading': 2.504077396776274,
#  'persuasions': 2.504077396776274,
#  'philosophy': 2.504077396776274,
#  'physiognomy': 2.504077396776274,
#  'place': 2.504077396776274,
#  'placed': 2.504077396776274,
#  'plainpalais': 2.504077396776274,
#  'playing': 2.504077396776274,
#  'plays': 2.504077396776274,
#  'pleased': 2.504077396776274,
#  'poets': 2.504077396776274,
#  'point': 2.09861228866811,
#  'poor': 2.504077396776274,
#  'possessed': 2.09861228866811,
#  'post': 2.504077396776274,
#  'poverty': 2.504077396776274,
#  'powers': 2.504077396776274,
#  'practice': 2.504077396776274,
#  'prepare': 2.504077396776274,
#  'presently': 2.504077396776274,
#  'preserver': 2.504077396776274,
#  'prevented': 2.09861228866811,
#  'pride': 2.504077396776274,
#  'principally': 2.504077396776274,
#  'probably': 2.504077396776274,
#  'proceeded': 2.504077396776274,
#  'procured': 2.504077396776274,
#  'profession': 2.504077396776274,
#  'professor': 2.504077396776274,
#  'professors': 2.504077396776274,
#  'proficiency': 2.504077396776274,
#  'prognosticated': 2.504077396776274,
#  'progress': 2.504077396776274,
#  'prolonged': 2.504077396776274,
#  'promised': 2.504077396776274,
#  'proof': 2.504077396776274,
#  'proportion': 2.504077396776274,
#  'prospect': 2.504077396776274,
#  'protracted': 2.504077396776274,
#  'proud': 2.504077396776274,
#  'public': 2.504077396776274,
#  'pursues': 2.504077396776274,
#  'pursuit': 2.504077396776274,
#  'qualities': 2.504077396776274,
#  'quickly': 2.504077396776274,
#  'quit': 2.504077396776274,
#  'quite': 2.504077396776274,
#  'rain': 2.504077396776274,
#  'rank': 2.504077396776274,
#  'rapid': 2.504077396776274,
#  'rapidly': 2.504077396776274,
#  'rapture': 2.504077396776274,
#  'rather': 2.09861228866811,
#  'ravings': 2.504077396776274,
#  'read': 2.09861228866811,
#  'real': 2.504077396776274,
#  'reassure': 2.504077396776274,
#  'recovered': 2.504077396776274,
#  'redeem': 2.504077396776274,
#  'refrain': 2.09861228866811,
#  'regret': 2.504077396776274,
#  'regretted': 2.504077396776274,
#  'relate': 2.504077396776274,
#  'relating': 2.504077396776274,
#  'remark': 2.504077396776274,
#  'remember': 2.504077396776274,
#  'render': 2.504077396776274,
#  'rendered': 2.09861228866811,
#  'republic': 2.504077396776274,
#  'repulsive': 2.504077396776274,
#  'reputation': 2.504077396776274,
#  'research': 2.504077396776274,
#  'resided': 2.504077396776274,
#  'residence': 2.504077396776274,
#  'resign': 2.504077396776274,
#  'resolved': 2.504077396776274,
#  'respected': 2.504077396776274,
#  'rest': 2.504077396776274,
#  'rested': 2.504077396776274,
#  'restrained': 2.504077396776274,
#  'result': 2.504077396776274,
#  'retreat': 2.504077396776274,
#  'retreated': 2.504077396776274,
#  'return': 2.09861228866811,
#  'returning': 2.09861228866811,
#  'returns': 2.504077396776274,
#  'romance': 2.504077396776274,
#  'roncesvalles': 2.504077396776274,
#  'round': 2.09861228866811,
#  'rowing': 2.504077396776274,
#  'run': 2.504077396776274,
#  'sad': 2.504077396776274,
#  'said': 2.09861228866811,
#  'sake': 2.504077396776274,
#  'same': 2.09861228866811,
#  'satisfied': 2.504077396776274,
#  'saved': 2.504077396776274,
#  'saw': 2.09861228866811,
#  'say': 2.504077396776274,
#  'scarcely': 2.504077396776274,
#  'scarlet': 2.504077396776274,
#  'scenes': 2.504077396776274,
#  'school': 2.504077396776274,
#  'schools': 2.504077396776274,
#  'science': 2.504077396776274,
#  'scientific': 2.504077396776274,
#  'scope': 2.504077396776274,
#  'seasons': 2.504077396776274,
#  'seat': 2.504077396776274,
#  'seated': 2.504077396776274,
#  'seclusion': 2.504077396776274,
#  'second': 2.504077396776274,
#  'secret': 2.504077396776274,
#  'see': 2.504077396776274,
#  'seek': 2.09861228866811,
#  'seemed': 2.09861228866811,
#  'seen': 2.504077396776274,
#  'selected': 2.09861228866811,
#  'sensations': 2.504077396776274,
#  'sense': 2.504077396776274,
#  'sepulchre': 2.504077396776274,
#  'serene': 2.504077396776274,
#  'serious': 2.504077396776274,
#  'service': 2.504077396776274,
#  'set': 2.504077396776274,
#  'seven': 2.504077396776274,
#  'seventeen': 2.504077396776274,
#  'several': 2.504077396776274,
#  'severe': 2.504077396776274,
#  'shall': 2.504077396776274,
#  'shapes': 2.504077396776274,
#  'she': 1.8109302162163288,
#  'shed': 2.504077396776274,
#  'shore': 2.504077396776274,
#  'should': 2.09861228866811,
#  'shrivelled': 2.504077396776274,
#  'sickbed': 2.09861228866811,
#  'sickened': 2.504077396776274,
#  'silence': 2.504077396776274,
#  'singular': 2.504077396776274,
#  'situations': 2.504077396776274,
#  'sixteen': 2.504077396776274,
#  'skims': 2.504077396776274,
#  'skin': 2.504077396776274,
#  'sly': 2.504077396776274,
#  'smile': 2.504077396776274,
#  'smiling': 2.504077396776274,
#  'smitten': 2.504077396776274,
#  'smoothed': 2.504077396776274,
#  'so': 1.8109302162163288,
#  'sockets': 2.504077396776274,
#  'sole': 2.504077396776274,
#  'solely': 2.504077396776274,
#  'solemnity': 2.504077396776274,
#  'some': 2.09861228866811,
#  'son': 2.09861228866811,
#  'songs': 2.504077396776274,
#  'soon': 2.09861228866811,
#  'sorrowful': 2.504077396776274,
#  'sought': 2.09861228866811,
#  'soul': 2.09861228866811,
#  'sound': 2.504077396776274,
#  'spark': 2.504077396776274,
#  'species': 2.504077396776274,
#  'spectators': 2.504077396776274,
#  'spent': 2.504077396776274,
#  'spirit': 2.09861228866811,
#  'stars': 2.504077396776274,
#  'state': 2.504077396776274,
#  'stay': 2.504077396776274,
#  'straight': 2.504077396776274,
#  'strangers': 2.504077396776274,
#  'strength': 2.504077396776274,
#  'student': 2.504077396776274,
#  'students': 2.504077396776274,
#  'studies': 2.504077396776274,
#  'study': 2.09861228866811,
#  'subjects': 2.504077396776274,
#  'sublime': 2.504077396776274,
#  'subsisted': 2.504077396776274,
#  'such': 2.09861228866811,
#  'suffered': 2.504077396776274,
#  'sufficient': 2.504077396776274,
#  'summers': 2.504077396776274,
#  'supply': 2.504077396776274,
#  'supposed': 2.504077396776274,
#  'surprise': 2.504077396776274,
#  'surrounded': 2.504077396776274,
#  'swiss': 2.09861228866811,
#  'symptoms': 2.504077396776274,
#  'syndics': 2.504077396776274,
#  'table': 2.504077396776274,
#  'taken': 2.504077396776274,
#  'tale': 2.504077396776274,
#  'talent': 2.504077396776274,
#  'task': 2.504077396776274,
#  'tear': 2.504077396776274,
#  'tears': 2.504077396776274,
#  'teeth': 2.504077396776274,
#  'temper': 2.504077396776274,
#  'tempest': 2.504077396776274,
#  'tempted': 2.504077396776274,
#  'term': 2.504077396776274,
#  'than': 1.8109302162163288,
#  'that': 1.0,
#  'the': 1.0,
#  'their': 2.504077396776274,
#  'them': 1.4054651081081644,
#  'themselves': 2.504077396776274,
#  'then': 2.504077396776274,
#  'theory': 2.504077396776274,
#  'there': 2.09861228866811,
#  'therefore': 1.8109302162163288,
#  'these': 1.587786664902119,
#  'they': 1.8109302162163288,
#  'thing': 2.504077396776274,
#  'things': 2.504077396776274,
#  'third': 2.504077396776274,
#  'thirst': 2.504077396776274,
#  'this': 1.251314428280906,
#  'those': 2.09861228866811,
#  'thought': 1.587786664902119,
#  'thoughts': 2.504077396776274,
#  'thousand': 2.09861228866811,
#  'thousands': 2.504077396776274,
#  'threw': 2.504077396776274,
#  'through': 2.09861228866811,
#  'thursday': 2.504077396776274,
#  'tidings': 2.504077396776274,
#  'time': 1.8109302162163288,
#  'times': 2.504077396776274,
#  'tinged': 2.504077396776274,
#  'to': 1.0,
#  'together': 2.504077396776274,
#  'toils': 2.504077396776274,
#  'torture': 2.504077396776274,
#  'town': 2.09861228866811,
#  'train': 2.504077396776274,
#  'tranquil': 2.504077396776274,
#  'tranquillity': 2.504077396776274,
#  'tremble': 2.504077396776274,
#  'trial': 2.504077396776274,
#  'tried': 2.504077396776274,
#  'triumphed': 2.504077396776274,
#  'true': 2.09861228866811,
#  'truest': 2.504077396776274,
#  'turbulence': 2.504077396776274,
#  'two': 1.8109302162163288,
#  'unbending': 2.504077396776274,
#  'uncertain': 2.504077396776274,
#  'uncle': 2.504077396776274,
#  'undertaking': 2.504077396776274,
#  'unfolded': 2.504077396776274,
#  'unfortunate': 2.504077396776274,
#  'union': 2.504077396776274,
#  'united': 2.09861228866811,
#  'university': 2.09861228866811,
#  'unknown': 2.504077396776274,
#  'unless': 2.504077396776274,
#  'until': 1.587786664902119,
#  'up': 1.8109302162163288,
#  'upon': 2.09861228866811,
#  'urged': 2.504077396776274,
#  'us': 1.587786664902119,
#  'usual': 2.504077396776274,
#  'utter': 2.504077396776274,
#  'vainly': 2.504077396776274,
#  'valuable': 2.504077396776274,
#  'variety': 2.504077396776274,
#  'very': 2.504077396776274,
#  'victor': 2.09861228866811,
#  'vigorous': 2.504077396776274,
#  'visit': 2.504077396776274,
#  'waited': 2.504077396776274,
#  'waldman': 2.504077396776274,
#  'walk': 2.504077396776274,
#  'wandering': 2.504077396776274,
#  'warm': 2.504077396776274,
#  'was': 1.1177830356563834,
#  'watchful': 2.504077396776274,
#  'watery': 2.504077396776274,
#  'ways': 2.504077396776274,
#  'we': 1.587786664902119,
#  'welcome': 2.504077396776274,
#  'well': 2.09861228866811,
#  'went': 2.09861228866811,
#  'were': 1.251314428280906,
#  'what': 2.504077396776274,
#  'when': 1.4054651081081644,
#  'where': 2.09861228866811,
#  'whether': 2.504077396776274,
#  'which': 1.1177830356563834,
#  'while': 2.504077396776274,
#  'whilst': 2.504077396776274,
#  'white': 2.504077396776274,
#  'whiteness': 2.504077396776274,
#  'who': 1.251314428280906,
#  'whole': 2.504077396776274,
#  'whom': 2.504077396776274,
#  'whose': 2.504077396776274,
#  'will': 2.09861228866811,
#  'william': 2.504077396776274,
#  'winter': 2.504077396776274,
#  'wish': 2.504077396776274,
#  'wishes': 2.504077396776274,
#  'with': 1.0,
#  'witnesses': 2.504077396776274,
#  'woeful': 2.504077396776274,
#  'women': 2.504077396776274,
#  'wonder': 2.504077396776274,
#  'wondrous': 2.504077396776274,
#  'word': 2.504077396776274,
#  'words': 2.504077396776274,
#  'work': 2.504077396776274,
#  'worked': 2.504077396776274,
#  'works': 2.504077396776274,
#  'world': 1.8109302162163288,
#  'worst': 2.504077396776274,
#  'worthy': 2.504077396776274,
#  'would': 1.8109302162163288,
#  'wrapped': 2.504077396776274,
#  'wretch': 2.504077396776274,
#  'wretched': 2.504077396776274,
#  'wretchedness': 2.09861228866811,
#  'write': 1.8109302162163288,
#  'writes': 2.504077396776274,
#  'written': 2.504077396776274,
#  'year': 2.504077396776274,
#  'years': 1.8109302162163288,
#  'yellow': 2.504077396776274,
#  'yet': 1.8109302162163288,
#  'yield': 2.504077396776274,
#  'yielded': 2.504077396776274,
#  'you': 1.587786664902119,
#  'younger': 2.09861228866811,
#  'your': 1.8109302162163288}

# %% [markdown]
# Hence, we can find the values assigned by TfDiff

# %% [markdown]
# Answer 2:

# %%
import nltk
import numpy as np
import itertools
nltk.download('universal_tagset')
nltk.download('brown')
from nltk.corpus import brown
sent_tag = brown.tagged_sents(tagset='universal')
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %%
mod_sent_tag=[]
for s in sent_tag:
  s.insert(0,('##','##'))
  s.append(('&&','&&'))
  mod_sent_tag.append(s)

# %%
split_num = int(len(mod_sent_tag)*0.9)
train_data = mod_sent_tag[0:split_num]
test_data = mod_sent_tag[split_num:]

# %%
split_num = int(len(mod_sent_tag)*0.9)
train_data = mod_sent_tag[0:split_num]
test_data = mod_sent_tag[split_num:]

# %%
train_word_tag = {}
for s in train_data:
  for (w,t) in s:
    w=w.lower()
    try:
      try:
        train_word_tag[t][w]+=1
      except:
        train_word_tag[t][w]=1
    except:
      train_word_tag[t]={w:1}

# %%
train_emission_prob={}
for k in train_word_tag.keys():
  train_emission_prob[k]={}
  count = sum(train_word_tag[k].values())
  for k2 in train_word_tag[k].keys():
    train_emission_prob[k][k2]=train_word_tag[k][k2]/count

# %%
bigram_tag_data = {}
for s in train_data:
  bi=list(nltk.bigrams(s))
  for b1,b2 in bi:
    try:
      try:
        bigram_tag_data[b1[1]][b2[1]]+=1
      except:
        bigram_tag_data[b1[1]][b2[1]]=1
    except:
      bigram_tag_data[b1[1]]={b2[1]:1}

# %%
bigram_tag_prob={}
for k in bigram_tag_data.keys():
  bigram_tag_prob[k]={}
  count=sum(bigram_tag_data[k].values())
  for k2 in bigram_tag_data[k].keys():
    bigram_tag_prob[k][k2]=bigram_tag_data[k][k2]/count

# %%
tags_of_tokens = {}
count=0
for s in train_data:
  for (w,t) in s:
    w=w.lower()
    try:
      if t not in tags_of_tokens[w]:
        tags_of_tokens[w].append(t)
    except:
      l = []
      l.append(t)
      tags_of_tokens[w] = l
        
for s in test_data:
  for (w,t) in s:
    w=w.lower()
    try:
      if t not in tags_of_tokens[w]:
        tags_of_tokens[w].append(t)
    except:
      l = []
      l.append(t)
      tags_of_tokens[w] = l

# %%
test_words=[]
test_tags=[]
for s in test_data:
  temp_word=[]
  temp_tag=[]
  for (w,t) in s:
    temp_word.append(w.lower())
    temp_tag.append(t)
  test_words.append(temp_word)
  test_tags.append(temp_tag)

# %%
predicted_tags = []                #intializing the predicted tags
for x in range(len(test_words)):   # for each tokenized sentence in the test data
  s = test_words[x]              
  storing_values = {}              
  for q in range(len(s)):
    step = s[q]
    if q == 1:                
      storing_values[q] = {}
      tags = tags_of_tokens[step]
      for t in tags:
        try:
          storing_values[q][t] = ['##',bigram_tag_prob['##'][t]*train_emission_prob[t][step]]
        except:
          storing_values[q][t] = ['##',0.0001]#*train_emission_prob[t][step]]
    
    if q>1:
      storing_values[q] = {}
      previous_states = list(storing_values[q-1].keys())   # loading the previous states
      current_states  = tags_of_tokens[step]               # loading the current states
      for t in current_states:                             
        temp = []
        for pt in previous_states:                         
          try:
            temp.append(storing_values[q-1][pt][1]*bigram_tag_prob[pt][t]*train_emission_prob[t][step])
          except:
            temp.append(storing_values[q-1][pt][1]*0.0001)
        max_temp_index = temp.index(max(temp))
        best_pt = previous_states[max_temp_index]
        storing_values[q][t]=[best_pt,max(temp)]

  #Backtracing to extract the best possible tags for the sentence
  pred_tags = []
  total_steps_num = storing_values.keys()
  last_step_num = max(total_steps_num)
  for bs in range(len(total_steps_num)):
    step_num = last_step_num - bs
    if step_num == last_step_num:
      pred_tags.append('&&')
      pred_tags.append(storing_values[step_num]['&&'][0])
    if step_num<last_step_num and step_num>0:
      pred_tags.append(storing_values[step_num][pred_tags[len(pred_tags)-1]][0])
  predicted_tags.append(list(reversed(pred_tags)))

# %%
right = 0 
wrong = 0
for i in range(len(test_tags)):
  gt = test_tags[i]
  pred = predicted_tags[i]
  for h in range(len(gt)):
    if gt[h] == pred[h]:
      right = right+1
    else:
      wrong = wrong +1 

print('Accuracy on the test data is: ',right/(right+wrong))
print('Loss on the test data is: ',wrong/(right+wrong))
# Out:
# Accuracy on the test data is:  0.971274904124965
# Loss on the test data is:  0.028725095875035075

# %% [markdown]
# Answer 3:

# %%
import pandas as pd
from nltk.corpus import stopwords 
from sklearn.feature_extraction import FeatureHasher
import re

# %%
news_data = pd.read_csv('/content/abcnews-date-text.csv')
news_data.sample(10)
# Out:
#          publish_date                                      headline_text
# 793729       20130610    more support urged to curb hedland homelessness
# 1090327      20170718          father of two allegedly paid 14yo for sex
# 1180242      20191026  the maths graduate turned carpenter university...
# 122849       20041022          asst principal to face child porn charges
# 882642       20140618  staff recruiting woes close mental health hosp...
# 72200        20040213     antarctic division defends use of russian ship
# 1012722      20160226              mass breastfeeding protest in bendigo
# 202347       20051123            angels beach wins northern rivers award
# 250998       20060722             fire rips through north melbourne club
# 154885       20050401         psychologist confident of being re elected

# %%
news_data.shape
# Out:
# (1186018, 2)

# %%
news_data = news_data.drop(columns ='publish_date')

# %%
news_data['headline_text_clean'] = news_data['headline_text'].map(lambda x: re.sub('[,\.!?]', '', x))

# %%
news_data['headline_text_clean'] = news_data['headline_text'].map(lambda x: x.lower())

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(news_data['headline_text_clean'])
# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# This shows the top words used in the document by using Topic Modelling.
